# %% [markdown]
# # Scenario 1: State tax board
#
# You are a data scientist in residence at the Iowa State tax board. The Iowa State legislature is considering changes in the liquor tax rates and wants a report of current liquor sales by county and projections for the rest of the year.
#
# **Goal for Scenario #1:** Your task is as follows:
#
# * Calculate the yearly liquor sales for each score using the provided data. You can add up the transactions for each year, and store sales in 2015 specifically will be used later as your target variable.
# * Use the data from 2015 to make a linear model using as many variables as you find useful to predict the yearly sales of each store. You must use the sales from Jan to March per store as one of your variables.
# * Use your model for 2015 to estimate total sales for each store in 2016, extrapolating from the sales so far for Jan-March of 2016.
# * Report your findings, including any projected increase or decrease in total sales (over the entire state) for the tax committee of the Iowa legislature.
# * Use cross-validation to check how your model predicts to held out data compared to the model metrics on the full dataset.
# * _Challenging Bonus_: We did not cover the topics of regularization for linear regression this week, but those feeling bold can try to use and understand regularizing linear regressions. This will require self-guided research/reading and scikit-learn functions that we have not gone over in class! Use cross-validation to tune the regularization parameter that maximizes R^2 on your holdout sets for the Ridge regression and the Lasso Regression. Do the regularized models perform better than the non-regularized model? Which regularized model performs better? What is the Ridge regression doing? What is the Lasso doing.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
# %matplotlib inline

liquor = pd.read_csv('Iowa_Liquor_Sales_Sample_10pct.csv')

# %%
liquor
liquor.isnull().sum()
# Out:
# Date                        0
# Store Number                0
# City                        0
# Zip Code                    0
# County Number            1077
# County                   1077
# Category                   68
# Category Name             632
# Vendor Number               0
# Item Number                 0
# Item Description            0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# dtype: int64

# %%
# so about 1100 missing county names/numbers, and 600 missing category names. They're mildly annoying,
# but don't impact the statistical value of revenue, really.

# %%
# Those column names are ugly and difficult. Let's make them more manageable.

names = [u'Date', u'Store_Number', u'City', u'Zip_Code', u'County_Number',
       u'County', u'Category', u'Category_Name', u'Vendor_Number',
       u'Item_No', u'Item_Desc', u'Volume_mL',
       u'State_Cost', u'State_Retail', u'Bottles_Sold',
       u'Sale_val', u'Volume_Sold_L', u'Volume_Sold_G']
liquor.columns = names

# %%
# Make sure that the above did what it was supposed to do
liquor.head()
# Out:
#          Date  Store_Number         City Zip_Code  County_Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category_Name  Vendor_Number  Item_No  \
# 0  1051100.0           APRICOT BRANDIES             55    54436
# 1  1011100.0           BLENDED WHISKIES            395    27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65    19067
# 3  1071100.0         AMERICAN COCKTAILS            395    59154
# 4  1031080.0             VODKA 80 PROOF            297    35918
#
#                    Item_Desc  Volume_mL State_Cost State_Retail  Bottles_Sold  \
# 0  Mr. Boston Apricot Brandy        750      $4.50        $6.75            12
# 1                    Tin Cup        750     $13.75       $20.63             2
# 2                   Jim Beam       1000     $12.59       $18.89            24
# 3    1800 Ultimate Margarita       1750      $9.50       $14.25             6
# 4         Five O'clock Vodka       1750      $7.20       $10.80            12
#
#   Sale_val  Volume_Sold_L  Volume_Sold_G
# 0   $81.00            9.0           2.38
# 1   $41.26            1.5           0.40
# 2  $453.36           24.0           6.34
# 3   $85.50           10.5           2.77
# 4  $129.60           21.0           5.55

# %%
# slice off the $
liquor['State_Cost'] = liquor.State_Cost.str.replace('$','')
liquor['State_Retail'] = liquor.State_Retail.str.replace('$','')
liquor['Sale_val'] = liquor['Sale_val'].str.replace('$','')

# %%
# convert strings to floats for aggregation
liquor['State_Cost'] = liquor.State_Cost.astype(float)
liquor['State_Retail'] = liquor.State_Retail.astype(float)
liquor['Sale_val'] = liquor['Sale_val'].astype(float)

# %%
# convert date to date/time
liquor['Date'] = pd.to_datetime(liquor.Date)

# %%
# Split out the year, month to get a bit more granularity
liquor['Month'] = liquor['Date'].dt.month
liquor['Year'] = liquor['Date'].dt.year

# %%
# # convert unnecessary floats to strings; this made sense at the time. I was trying to do
# something specific here, but only upsets Jupyter afterwarads

# liquor['Store_Number'] = liquor.Store_Number.astype(str)
# liquor['County_Number'] = liquor.County_Number.astype(str)
# liquor['Vendor_Number'] = liquor.Vendor_Number.astype(str)
# liquor['Item_No'] = liquor.Item_No.astype(str)
# liquor.dtypes

# %%
# There seem to be a lot of unnecessary columns here. Although it's difficult to say what is predictive,
# a few stand out as clearly not. E.g., the volume of a given bottle, the vendor number, the item number
# We're interested in total sales, by store, and there's not a lot here that is likely to be predictive

# %%
liquor.drop(['Vendor_Number', 'Item_No', 'Volume_mL'], axis=1, inplace=True)

# %%
# Just out of curiosity, what's the state's markup on the hooch?
liquor['State_Margin'] = ((liquor.State_Retail - liquor.State_Cost) / liquor.State_Retail)

# %%
liquor['State_Margin'].describe()
# Out:
# count    270955.000000
# mean          0.334214
# std           0.004976
# min           0.000000
# 25%           0.333333
# 50%           0.333333
# 75%           0.333603
# max           0.714286
# Name: State_Margin, dtype: float64

# %%
profit = liquor['State_Margin'].median()
profit
# Out:
# 0.33333333333333337

# %%
# Mean, median state margin is 33%, with almost no standard deviation

# %%
#Rounding because we are dealing with currency; it makes sense to 
liquor.round(2)
# Out:
#              Date  Store_Number             City Zip_Code  County_Number  \
# 0      2015-11-04          3717           SUMNER    50674            9.0
# 1      2016-03-02          2614        DAVENPORT    52807           82.0
# 2      2016-02-11          2106      CEDAR FALLS    50613            7.0
# 3      2016-02-03          2501             AMES    50010           85.0
# 4      2015-08-18          3654          BELMOND    50421           99.0
# 5      2015-04-20          2569     CEDAR RAPIDS    52402           57.0
# 6      2015-08-05          2596          OTTUMWA    52501           90.0
# 7      2015-06-25          3456       CLEAR LAKE    50428           17.0
# 8      2016-01-04          4757        BONDURANT    50035           77.0
# 9      2015-11-10          4346       SHELLSBURG    52332            6.0
# 10     2015-09-28          2648  WEST DES MOINES    50265           77.0
# 11     2015-10-28          2600        OSKALOOSA    52577           62.0
# 12     2015-01-22          3858        DAVENPORT    52806           82.0
# 13     2016-02-29          4673       WEST POINT    52656           56.0
# 14     2016-01-04          2670       CORALVILLE    52241           52.0
# 15     2015-06-10          3717           SUMNER    50674            9.0
# 16     2016-02-25          2130         WATERLOO    50703            7.0
# 17     2015-12-29          2600        OSKALOOSA    52577           62.0
# 18     2015-12-26          4604           NEWTON    50208           50.0
# 19     2015-03-04          2614        DAVENPORT    52807           82.0
# 20     2015-01-16          2590     CEDAR RAPIDS    52402           57.0
# 21     2015-01-13          3942           TOLEDO    52342           86.0
# 22     2015-03-24          3981     SIOUX CENTER    51250           84.0
# 23     2015-11-12          4376       MASON CITY    50401           17.0
# 24     2016-03-14          2618     CEDAR RAPIDS    52402           57.0
# 25     2015-02-03          3390          MILFORD    51351           30.0
# 26     2015-11-23          3565        IOWA CITY    52246           52.0
# 27     2015-04-21          3963   COUNCIL BLUFFS    51501           78.0
# 28     2015-12-01          4375           GRIMES    50111           77.0
# 29     2015-01-14          2545        IOWA CITY    52245           52.0
# ...           ...           ...              ...      ...            ...
# 270925 2015-01-05          2837         WATERLOO    50702            7.0
# 270926 2015-12-26          2478          ALTOONA    50009           77.0
# 270927 2015-08-31          2633       DES MOINES    50320           77.0
# 270928 2015-10-07          3896        IOWA CITY    52240           52.0
# 270929 2016-01-25          5070           WILTON    52778           70.0
# 270930 2015-10-13          4634     CEDAR RAPIDS    52402           57.0
# 270931 2015-05-26          2602     WEBSTER CITY    50595           40.0
# 270932 2015-06-18          4604           NEWTON    50208           50.0
# 270933 2015-02-26          4987             AMES    50010           85.0
# 270934 2015-03-18          2623       SIOUX CITY    51104           97.0
# 270935 2015-06-08          5126       DES MOINES    50310           77.0
# 270936 2015-03-31          2552     CEDAR RAPIDS    52404           57.0
# 270937 2015-01-27          2553          CRESTON    50801           88.0
# 270938 2015-04-29          3890     CEDAR RAPIDS    52405           57.0
# 270939 2015-05-04          4876         HIAWATHA    52233           57.0
# 270940 2015-01-21          2523      CENTERVILLE    52544            4.0
# 270941 2015-02-09          4856           LISBON    52253           57.0
# 270942 2015-06-15          2512        IOWA CITY    52240           52.0
# 270943 2015-10-21          4438             AMES    50010           85.0
# 270944 2016-03-22          2620  WINDSOR HEIGHTS    50311           77.0
# 270945 2015-06-11          2627       DES MOINES    50310           77.0
# 270946 2015-11-24          5162        URBANDALE    50322           77.0
# 270947 2015-05-12          4375           GRIMES    50111           77.0
# 270948 2015-04-08          2545        IOWA CITY    52245           52.0
# 270949 2015-07-21          2529     CEDAR RAPIDS    52405           57.0
# 270950 2015-12-22          4057       DES MOINES    50316           77.0
# 270951 2015-11-04          5151        IDA GROVE    51445           47.0
# 270952 2015-10-20          5152         WATERLOO    50702            7.0
# 270953 2015-11-20          3562  WEST BURLINGTON    52655           29.0
# 270954 2015-01-27          4446        URBANDALE    50322           77.0
#
#                County   Category                       Category_Name  \
# 0              Bremer  1051100.0                    APRICOT BRANDIES
# 1               Scott  1011100.0                    BLENDED WHISKIES
# 2          Black Hawk  1011200.0           STRAIGHT BOURBON WHISKIES
# 3               Story  1071100.0                  AMERICAN COCKTAILS
# 4              Wright  1031080.0                      VODKA 80 PROOF
# 5                Linn  1041100.0                   AMERICAN DRY GINS
# 6             Wapello  1051010.0             AMERICAN GRAPE BRANDIES
# 7         Cerro Gordo  1012100.0                   CANADIAN WHISKIES
# 8                Polk  1032080.0                      IMPORTED VODKA
# 9              Benton  1081315.0                   CINNAMON SCHNAPPS
# 10               Polk  1011250.0      SINGLE BARREL BOURBON WHISKIES
# 11            Mahaska  1071100.0                  AMERICAN COCKTAILS
# 12              Scott  1012100.0                   CANADIAN WHISKIES
# 13                Lee  1081300.0                 PEPPERMINT SCHNAPPS
# 14            Johnson  1031200.0                      VODKA FLAVORED
# 15             Bremer  1051100.0                    APRICOT BRANDIES
# 16         Black Hawk  1031100.0                     100 PROOF VODKA
# 17            Mahaska  1031200.0                      VODKA FLAVORED
# 18             Jasper  1081700.0         DISTILLED SPIRITS SPECIALTY
# 19              Scott  1012100.0                   CANADIAN WHISKIES
# 20               Linn  1031200.0                      VODKA FLAVORED
# 21               Tama  1012100.0                   CANADIAN WHISKIES
# 22              Sioux  1011100.0                    BLENDED WHISKIES
# 23        Cerro Gordo  1022100.0                             TEQUILA
# 24               Linn  1031080.0                      VODKA 80 PROOF
# 25          Dickinson  1011300.0                  TENNESSEE WHISKIES
# 26            Johnson  1012100.0                   CANADIAN WHISKIES
# 27      Pottawattamie  1011100.0                    BLENDED WHISKIES
# 28               Polk  1031080.0                      VODKA 80 PROOF
# 29            Johnson  1081600.0                     WHISKEY LIQUEUR
# ...               ...        ...                                 ...
# 270925     Black Hawk  1081200.0                      CREAM LIQUEURS
# 270926           Polk  1022100.0                             TEQUILA
# 270927           Polk  1031200.0                      VODKA FLAVORED
# 270928        Johnson  1031080.0                      VODKA 80 PROOF
# 270929      Muscatine  1031080.0                      VODKA 80 PROOF
# 270930           Linn  1031080.0                      VODKA 80 PROOF
# 270931       Hamilton  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 270932         Jasper  1011300.0                  TENNESSEE WHISKIES
# 270933          Story  1062310.0                          SPICED RUM
# 270934       Woodbury  1051110.0                 BLACKBERRY BRANDIES
# 270935           Polk  1011300.0                  TENNESSEE WHISKIES
# 270936           Linn  1022100.0                             TEQUILA
# 270937          Union  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270938           Linn  1031080.0                      VODKA 80 PROOF
# 270939           Linn  1031200.0                      VODKA FLAVORED
# 270940      Appanoose  1012200.0                     SCOTCH WHISKIES
# 270941           Linn  1031080.0                      VODKA 80 PROOF
# 270942        Johnson  1011100.0                    BLENDED WHISKIES
# 270943          Story  1011200.0           STRAIGHT BOURBON WHISKIES
# 270944           Polk  1081240.0               GREEN CREME DE MENTHE
# 270945           Polk  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 270946           Polk  1031080.0                      VODKA 80 PROOF
# 270947           Polk  1062310.0                          SPICED RUM
# 270948        Johnson  1062300.0                        FLAVORED RUM
# 270949           Linn  1031100.0                     100 PROOF VODKA
# 270950           Polk  1022100.0                             TEQUILA
# 270951            Ida  1011200.0           STRAIGHT BOURBON WHISKIES
# 270952     Black Hawk  1011300.0                  TENNESSEE WHISKIES
# 270953     Des Moines  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270954           Polk  1031080.0                      VODKA 80 PROOF
#
#                                     Item_Desc  State_Cost  State_Retail  \
# 0                   Mr. Boston Apricot Brandy        4.50          6.75
# 1                                     Tin Cup       13.75         20.63
# 2                                    Jim Beam       12.59         18.89
# 3                     1800 Ultimate Margarita        9.50         14.25
# 4                          Five O'clock Vodka        7.20         10.80
# 5                           New Amsterdam Gin       13.32         19.98
# 6                               Korbel Brandy        6.66          9.99
# 7                        Canadian Club Whisky       15.75         23.63
# 8                Absolut Swedish Vodka 80 Prf       11.49         17.24
# 9                          Dekuyper Hot Damn!        7.62         11.43
# 10           Knob Creek Single Barrel Reserve       26.24         39.36
# 11              Chi-Chi's Margarita W/tequila        6.00          9.25
# 12                       Windsor Canadian Pet        8.92         13.38
# 13                              Kinky Liqueur       10.00         15.00
# 14                      Uv Red (cherry) Vodka        7.50         11.25
# 15                  Mr. Boston Apricot Brandy        4.50          6.75
# 16                         Five O'clock Vodka        1.13          1.70
# 17                              Uv Cake Vodka        6.50          9.75
# 18                            Juarez Gold Dss        4.92          7.38
# 19               Lord Calvert Canadian Whisky        9.97         14.96
# 20                       44 North Huckleberry       14.25         21.38
# 21                      Black Velvet Traveler        5.23          7.85
# 22                Seagrams 7 Crown Bl Whiskey        7.00         10.50
# 23      Jose Cuervo Especial Reposado Tequila       10.49         15.74
# 24                     Five O'clock PET Vodka        3.37          5.06
# 25              Jack Daniels Old #7 Black Lbl       17.90         26.85
# 26           Crown Royal Canadian Whisky Mini        7.35         11.03
# 27                      Hawkeye Blend Whiskey        3.50          5.25
# 28                               UV Vodka PET       10.99         16.49
# 29                     Piehole Apple Pie Mini        4.90          7.35
# ...                                       ...         ...           ...
# 270925             Emmets Irish Cream Liqueur        6.00          9.00
# 270926                           Patron Anejo       31.00         46.50
# 270927                        Smirnoff Orange        9.25         13.88
# 270928                    Mccormick Vodka Pet        1.80          2.70
# 270929                         Phillips Vodka        3.57          5.36
# 270930                     Five O'clock Vodka        1.93          2.90
# 270931        Dekuyper Signature Blue Curacao        5.25          7.88
# 270932          Jack Daniels Old #7 Black Lbl       29.67         44.51
# 270933         Captain Morgan Original Spiced        9.00         13.50
# 270934           Mr. Boston Blackberry Brandy       10.00         15.00
# 270935          Jack Daniel's Tennessee Honey       15.07         22.61
# 270936  Jose Cuervo Especial Reposado Tequila       10.49         15.74
# 270937      Chambord Liqueur Royale De France       18.56         27.84
# 270938                  Smirnoff Vodka 80 Prf        4.75          7.13
# 270939                          Uv Cake Vodka        4.89          7.34
# 270940                   Famous Grouse Scotch       12.03         18.05
# 270941       Fleischmann's Royal Vodka 80 Prf        6.68         10.27
# 270942         Kessler Blend Whiskey Traveler        5.51          8.27
# 270943                          Jim Beam Mini        6.83         10.25
# 270944        Paramount Creme De Menthe/green        4.75          7.13
# 270945                       Barton Light Rum        0.89          1.34
# 270946                            Titos Vodka        9.65         14.48
# 270947              Captain Morgan Spiced Rum        5.00          7.50
# 270948               Bacardi Pineapple Fusion        8.50         12.75
# 270949                        McCormick Vodka        4.13          6.20
# 270950             Patron Tequila Silver Mini       20.30         30.45
# 270951              Evan Williams Str Bourbon        7.47         11.21
# 270952          Jack Daniels Old #7 Black Lbl       15.07         22.61
# 270953                   Jagermeister Liqueur       26.05         39.08
# 270954                  Smirnoff Vodka 80 Prf        2.75          4.13
#
#         Bottles_Sold  Sale_val  Volume_Sold_L  Volume_Sold_G  Month  Year  \
# 0                 12     81.00           9.00           2.38     11  2015
# 1                  2     41.26           1.50           0.40      3  2016
# 2                 24    453.36          24.00           6.34      2  2016
# 3                  6     85.50          10.50           2.77      2  2016
# 4                 12    129.60          21.00           5.55      8  2015
# 5                  6    119.88          10.50           2.77      4  2015
# 6                  3     29.97           2.25           0.59      8  2015
# 7                  2     47.26           3.50           0.92      6  2015
# 8                  4     68.96           3.00           0.79      1  2016
# 9                  2     22.86           2.00           0.53     11  2015
# 10                 6    236.16           4.50           1.19      9  2015
# 11                 6     55.50          10.50           2.77     10  2015
# 12                 1     13.38           1.75           0.46      1  2015
# 13                12    180.00           9.00           2.38      2  2016
# 14                12    135.00          12.00           3.17      1  2016
# 15                 4     27.00           3.00           0.79      6  2015
# 16                48     81.60           9.60           2.54      2  2016
# 17                12    117.00           9.00           2.38     12  2015
# 18                24    177.12          24.00           6.34     12  2015
# 19                 6     89.76          10.50           2.77      3  2015
# 20                 2     42.76           1.50           0.40      1  2015
# 21                12     94.20           9.00           2.38      1  2015
# 22                12    126.00           9.00           2.38      3  2015
# 23                12    188.88           9.00           2.38     11  2015
# 24                12     60.72           9.00           2.38      3  2016
# 25                24    644.40          24.00           6.34      2  2015
# 26                 1     11.03           0.30           0.08     11  2015
# 27                 3     15.75           2.25           0.59      4  2015
# 28                 6     98.94          10.50           2.77     12  2015
# 29                 1      7.35           0.50           0.13      1  2015
# ...              ...       ...            ...            ...    ...   ...
# 270925             4     36.00           3.00           0.79      1  2015
# 270926             6    279.00           4.50           1.19     12  2015
# 270927            12    166.56          12.00           3.17      8  2015
# 270928            48    129.60          18.00           4.76     10  2015
# 270929             4     21.44           3.00           0.79      1  2016
# 270930            12     34.80           4.50           1.19     10  2015
# 270931            12     94.56           9.00           2.38      5  2015
# 270932             2     89.02           3.50           0.92      6  2015
# 270933             3     40.50           2.25           0.59      2  2015
# 270934             2     30.00           3.50           0.92      3  2015
# 270935             3     67.83           2.25           0.59      6  2015
# 270936            12    188.88           9.00           2.38      3  2015
# 270937             1     27.84           0.75           0.20      1  2015
# 270938             3     21.39           1.12           0.30      4  2015
# 270939             6     44.04           3.00           0.79      5  2015
# 270940             4     72.20           3.00           0.79      1  2015
# 270941             6     61.62          10.50           2.77      2  2015
# 270942            12     99.24           9.00           2.38      6  2015
# 270943             1     10.25           0.50           0.13     10  2015
# 270944             2     14.26           1.50           0.40      3  2016
# 270945            48     64.32           4.80           1.27      6  2015
# 270946             4     57.92           3.00           0.79     11  2015
# 270947             6     45.00           2.25           0.59      5  2015
# 270948             3     38.25           2.25           0.59      4  2015
# 270949             3     18.60           3.00           0.79      7  2015
# 270950             4    121.80           1.20           0.32     12  2015
# 270951             3     33.63           2.25           0.59     11  2015
# 270952             6    135.66           4.50           1.19     10  2015
# 270953             6    234.48          10.50           2.77     11  2015
# 270954             8     33.04           1.60           0.42      1  2015
#
#         State_Margin
# 0               0.33
# 1               0.33
# 2               0.33
# 3               0.33
# 4               0.33
# 5               0.33
# 6               0.33
# 7               0.33
# 8               0.33
# 9               0.33
# 10              0.33
# 11              0.35
# 12              0.33
# 13              0.33
# 14              0.33
# 15              0.33
# 16              0.34
# 17              0.33
# 18              0.33
# 19              0.33
# 20              0.33
# 21              0.33
# 22              0.33
# 23              0.33
# 24              0.33
# 25              0.33
# 26              0.33
# 27              0.33
# 28              0.33
# 29              0.33
# ...              ...
# 270925          0.33
# 270926          0.33
# 270927          0.33
# 270928          0.33
# 270929          0.33
# 270930          0.33
# 270931          0.33
# 270932          0.33
# 270933          0.33
# 270934          0.33
# 270935          0.33
# 270936          0.33
# 270937          0.33
# 270938          0.33
# 270939          0.33
# 270940          0.33
# 270941          0.35
# 270942          0.33
# 270943          0.33
# 270944          0.33
# 270945          0.34
# 270946          0.33
# 270947          0.33
# 270948          0.33
# 270949          0.33
# 270950          0.33
# 270951          0.33
# 270952          0.33
# 270953          0.33
# 270954          0.33
#
# [270955 rows x 18 columns]

# %%
# Records for 2016
liquor_16 = liquor[(liquor.Year == 2016)]

# %%
liquor_16.Date.value_counts()
# Out:
# 2016-01-04    1311
# 2016-01-25    1296
# 2016-03-14    1219
# 2016-01-05    1208
# 2016-03-09    1169
# 2016-03-22    1168
# 2016-03-15    1164
# 2016-02-02    1161
# 2016-03-16    1150
# 2016-03-28    1138
# 2016-01-06    1126
# 2016-02-10    1121
# 2016-03-07    1120
# 2016-03-21    1115
# 2016-02-24    1112
# 2016-01-27    1110
# 2016-02-01    1106
# 2016-03-30    1103
# 2016-03-02    1102
# 2016-02-23    1100
# 2016-02-03    1100
# 2016-02-17    1099
# 2016-02-16    1097
# 2016-02-08    1094
# 2016-01-20    1094
# 2016-01-26    1076
# 2016-01-19    1070
# 2016-03-08    1054
# 2016-02-22    1054
# 2016-02-15    1046
# 2016-01-11    1045
# 2016-03-01    1041
# 2016-02-09    1039
# 2016-02-29    1037
# 2016-03-23    1031
# 2016-01-13    1019
# 2016-01-12    1012
# 2016-03-29     984
# 2016-01-07     842
# 2016-03-10     836
# 2016-03-03     808
# 2016-02-25     783
# 2016-02-11     769
# 2016-03-24     746
# 2016-02-04     742
# 2016-02-18     730
# 2016-01-21     713
# 2016-03-17     711
# 2016-01-14     703
# 2016-03-31     670
# 2016-01-28     665
# 2016-01-15     551
# 2016-03-04       1
# Name: Date, dtype: int64

# %%
# Records for 2015
liquor_15 = liquor[(liquor.Year == 2015)]

# %%
# Monthly total revenue for 2015
liquor_15_monthly = liquor_15.groupby('Month').Sale_val.agg(['sum'])
liquor_15_monthly
# Out:
#               sum
# Month
# 1      1858000.63
# 2      2037903.48
# 3      2257891.78
# 4      2302566.62
# 5      2259716.10
# 6      2754960.95
# 7      2175922.14
# 8      2164753.72
# 9      2387918.92
# 10     2810088.85
# 11     2460865.60
# 12     3056656.60

# %%
#Split 2015 into Quarters
q1_15 = liquor_15[(liquor_15.Month <= 3)]
q2_15 = liquor_15[((liquor_15.Month > 3) & (liquor_15.Month <= 6))]
q3_15 = liquor_15[((liquor_15.Month < 6) & (liquor_15.Month <=9))]
q4_15 = liquor_15[(liquor_15.Month > 9)]

# %%
# The next two cells are playing around with transpose and stack/unstack. I was planning to check revenue by store 
# month by month before I realized that the aggregated figures would just work better. I did, ultimately, get each 
# store on a single line, with each month's revenue broken out. Rather pleased with that.

# %%
# liquor_15_monthly.transpose()

# %%
# mo_sale_15 = liquor_15.groupby(['Store_Number', 'Month']).Sale_val.agg(['sum']).transpose()
# s = mo_sale_15.stack().transpose()

# %%
# Aggregating mean volume sold per store, annually
mean_vol_15 = q1_15.groupby(['Store_Number']).Volume_Sold_L.agg(['mean'])

# %%
# Total for liquor sales in 2015 across all stores
sales_15 = round(sum(liquor_15.Sale_val), 2)
sales_15
# Out:
# 28527245.39

# %%
# Estimated State profit for liquor sales in 2015
profit_15 = sales_15 * profit
round(profit_15,2)
# Out:
# 9509081.8

# %%
# Quarterly Sales by store, q1 15
q1_15_stores = q1_15.groupby('Store_Number').Sale_val.agg(['sum'])

# %%
# Mean quarterly liquor sales, by store
q1_15.groupby('Store_Number').Volume_Sold_L.agg(['mean'])

# %%
# Summing store sales in 15
store_sales_15 = liquor_15.groupby('Store_Number').Sale_val.agg(['sum'])

# %%
# Begin setting up a series of dataframes from the GroupBy objects in order to build the data frame that I required
# Considering how repetitive it is, there is almost certainly a way to write a function that does this. Something
# to think about later.
store_15 = ['Annual_Sales_15']

store_sales_15.columns = store_15
q1_15 = ['Q1_15_sales']
q1_15_stores.columns = q1_15
df1 = pd.merge(store_sales_15, q1_15_stores, left_index=True, right_index=True, how='outer')

# %%
# confirm that the first constructed dataframe is what I need it to be
df1.dtypes

# %%
# Second dataframe for merging
annl_vol_15 = liquor_15.groupby('Store_Number').Volume_Sold_L.agg(['sum'])
df2 = pd.merge(df1, annl_vol_15, left_index=True, right_index=True, how='outer')
df2.rename(columns = {'sum':'Annual_Volume'}, inplace=True)

# %%
# Third dataframe, initial modeling data
df3 = pd.merge(df2, mean_vol_15, left_index=True, right_index=True, how='outer')
df3
# Out:
#               Annual_Sales_15  Q1_15_sales  Annual_Volume       mean
# Store_Number
# 2106                146326.22     39287.29        9731.85  19.582171
# 2113                  9310.22      2833.25         659.85   4.216905
# 2130                111871.43     24272.57        6891.37  16.635057
# 2152                  7721.08      2003.46         633.37   4.741875
# 2178                 24324.18      5856.41        1917.12   8.537708
# 2190                121689.06     29452.92        6322.17   4.802824
# 2191                125093.49     29085.57        8053.32  12.962119
# 2200                 22811.55      4900.43        1817.24   4.377619
# 2205                 24681.39      6407.74        1556.91   5.362571
# 2228                 17462.07      5193.97        1367.65   6.760333
# 2233                 29553.34      5374.55        2480.69   9.763953
# 2238                 11762.56       858.61         705.75   6.000000
# 2248                 67682.06     12663.68        2815.35   6.431089
# 2285                 76927.11     10019.12        3860.35   8.680172
# 2290                 56514.43     12191.26        3626.20   5.109875
# 2327                 10245.14      2253.60         822.28   4.262093
# 2353                 54000.55     17382.60        4504.65  16.620202
# 2367                  5010.83      2023.44         346.75   7.181818
# 2413                 90065.02     22459.16        6261.29  13.613894
# 2445                  7189.48      1215.08         571.79   2.972188
# 2448                 17740.70      5655.92        1245.53   3.259107
# 2459                  7352.33      1609.57         607.24   6.227273
# 2460                 33731.76      6746.61        2782.46   7.015366
# 2465                 25831.80      5615.99        1713.20   4.082857
# 2475                 10681.07      5672.76        1044.94  32.707500
# 2478                 19840.65      4459.85        1038.00  11.052632
# 2487                 28900.96      7256.60        2547.85   4.257417
# 2498                  2259.67       279.22         230.12   2.787000
# 2500                149121.63     40234.90       10039.15  11.208369
# 2501                144833.66     31412.95        9959.40   6.755919
# ...                       ...          ...            ...        ...
# 5180                  2239.44          NaN         175.25        NaN
# 5181                   963.04          NaN          65.30        NaN
# 5182                  2612.94          NaN         164.70        NaN
# 5183                   916.80          NaN          61.80        NaN
# 5185                  1077.39          NaN          73.00        NaN
# 5186                   298.86          NaN          16.49        NaN
# 5187                  4239.11          NaN         218.31        NaN
# 5188                  1887.73          NaN          96.40        NaN
# 5189                   604.20          NaN          39.00        NaN
# 5190                  1161.73          NaN          69.75        NaN
# 5191                   303.90          NaN          19.50        NaN
# 5192                    90.00          NaN           4.50        NaN
# 5193                   139.50          NaN           9.00        NaN
# 5196                   682.85          NaN          37.97        NaN
# 5198                  3985.06          NaN         200.43        NaN
# 5199                  2046.22          NaN         148.80        NaN
# 5201                   289.78          NaN           8.63        NaN
# 5203                   928.49          NaN          79.50        NaN
# 5204                   790.44          NaN          57.10        NaN
# 5205                    39.02          NaN           3.50        NaN
# 5206                   500.90          NaN          26.35        NaN
# 5207                  3197.95          NaN         135.06        NaN
# 5212                   504.54          NaN          36.75        NaN
# 5213                   180.00          NaN           9.60        NaN
# 5215                    56.03          NaN           1.80        NaN
# 9001                 28208.52      2341.08         639.00  11.700000
# 9002                 37700.52      4865.16        1242.00  15.000000
# 9010                  5757.96      3861.60         212.40  16.875000
# 9013                  2217.48          NaN         171.00        NaN
# 9018                  6435.00          NaN         225.00        NaN
#
# [1372 rows x 4 columns]

# %%
# Since our test set is only q1 See how things correlate here
df3.corr()
# Out:
#                  Annual_Sales_15  Q1_15_sales  Annual_Volume      mean
# Annual_Sales_15         1.000000     0.981456       0.992339  0.356906
# Q1_15_sales             0.981456     1.000000       0.972804  0.385705
# Annual_Volume           0.992339     0.972804       1.000000  0.377593
# mean                    0.356906     0.385705       0.377593  1.000000

# %%
df3.fillna(value=0, inplace=True)

# %%
names3 = [u'Annual_Sales_15', u'Q1_15_sales', u'Annual_Volume', u'Q1_Mean_LVol_Mo']
df3.columns = names3

# %%
df3.shape
# Out:
# (1372, 4)

# %% [markdown]
# # Modeling Modeling now we go..

# %%
linr = LinearRegression()

# %%
# Best Fit Model for 2015, based on the variables I have selected
features = ['Q1_15_sales','Q1_Mean_LVol_Mo']
target = ['Annual_Sales_15']
X = df3[features]
y = df3[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=76)
model = linr.fit(X_train,y_train)
y_predicts = model.predict(X_test)

print np.sqrt(mean_squared_error(y_test, y_predicts))
# Out:
# 8376.11406773

# %%
# And, since the object is to predict the annual sales for 2016, we take our lovely little model and apply it to 
# q1 sales for 2016

# %%
store_sales_16 = liquor_16.groupby('Store_Number').Sale_val.agg(['sum'])
store_sales_16.head(4)
# Out:
#                    sum
# Store_Number
# 2106          30523.75
# 2113           2065.90
# 2130          27856.11
# 2152           1376.43

# %%
vol_16 = liquor_16.groupby('Store_Number').Volume_Sold_L.agg(['mean'])
vol_16.head(3)
# Out:
#                    mean
# Store_Number
# 2106          16.675197
# 2113           4.783784
# 2130          13.306838

# %%
df_mod = pd.merge(store_sales_16, vol_16, left_index=True, right_index=True, how='outer')

df_mod.columns
# Out:
# Index([u'sum', u'mean'], dtype='object')

# %%
df_mod['16_annl'] = store_sales_16 * 4

# %%
# Train the model on the Q1 16 data and get some predictions
X_ind = df_mod[['sum', 'mean']]
y_dep = df_mod['16_annl']
linr.fit(X_ind, y_dep)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Annl_Pred = linr.predict(X_ind)

# %%
Annl_Pred = sum(Annl_Pred) * 4

# %%
Annl_Pred
# Out:
# 102391960.95999965

# %% [markdown]
# # Just for fun and games: Most popular category by year

# %%
liquor.groupby(['Year','Category_Name']).Volume_Sold_L.agg(['sum']).sort_values(by='sum', ascending=False).head(10)
